# %%
pip install sentence-transformers faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 24.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight and fast

documents = [
    "The Burj Khalifa is the tallest building in the world.",
    "Eiffel Tower is located in Paris.",
    "Python is a popular programming language.",
    "Apple is a tech company known for iPhones."
]

doc_embeddings = model.encode(documents)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
import faiss
import numpy as np

dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(doc_embeddings))

# %%
query = "what is the most used language?"
query_embedding = model.encode([query])

top_k = 2
distances, indices = index.search(np.array(query_embedding), top_k)

print("\nTop Results:")
for i in indices[0]:
    print(documents[i])
# Out:
# Top Results:
# Python is a popular programming language.
# The Burj Khalifa is the tallest building in the world.

# %%
pip install pandas sentence-transformers faiss-cpu

# %%
# prompt: upload the data set

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-144bf644-4d55-45b2-aa47-1899c0c2400c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-144bf644-4d55-45b2-aa47-1899c0c2400c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: unzip the folder, extract file

import zipfile
import io

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  # Assume the uploaded file is a zip file
  try:
    with zipfile.ZipFile(io.BytesIO(uploaded[fn]), 'r') as zip_ref:
      zip_ref.extractall('.')  # Extract to the current directory
      print(f"Extracted {fn}")
  except zipfile.BadZipFile:
    print(f"Error: {fn} is not a valid zip file.")
  except Exception as e:
    print(f"An error occurred while extracting {fn}: {e}")

# List files to see the extracted content (optional)
# !ls
# Out:
# User uploaded file "bbc_news.csv.zip" with length 1881854 bytes
# Extracted bbc_news.csv.zip
# bbc_news.csv  bbc_news.csv.zip	sample_data

# %%
df = pd.read_csv('bbc_news.csv')
print(df.columns)
# Out:
# Index(['title', 'pubDate', 'guid', 'link', 'description'], dtype='object')

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss

# Load your dataset
df = pd.read_csv('bbc_news.csv')  # Replace with your file
texts = df['description'].tolist()

# Load sentence embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(texts, convert_to_numpy=True)

# %%
# Create FAISS index
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# %%
def semantic_search(query, k=3):
    query_vec = model.encode([query], convert_to_numpy=True)
    distances, indices = index.search(query_vec, k)
    return df.iloc[indices[0]]

# Try it
results = semantic_search("where is the flood?")
print(results)
# Out:
#                                                    title  \
# 1764   Durban floods: Is it a consequence of climate ...
# 18042     The Ukraine dam breach rescue... in 62 seconds
# 7896   Bengaluru floods: How families struggled to fi...
#
#                              pubDate  \
# 1764   Thu, 14 Apr 2022 23:11:18 GMT
# 18042  Wed, 07 Jun 2023 11:21:44 GMT
# 7896   Mon, 12 Sep 2022 06:36:21 GMT
#
#                                                     guid  \
# 1764                 https://www.bbc.co.uk/news/61107685
# 18042   https://www.bbc.co.uk/news/world-europe-65832665
# 7896   https://www.bbc.co.uk/news/world-asia-india-62...
#
#                                                     link  \
# 1764   https://www.bbc.co.uk/news/61107685?at_medium=...
# 18042  https://www.bbc.co.uk/news/world-europe-658326...
# 7896   https://www.bbc.co.uk/news/world-asia-india-62...
#
#                                              description
# ...
